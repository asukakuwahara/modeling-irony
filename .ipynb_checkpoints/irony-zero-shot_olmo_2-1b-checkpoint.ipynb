# %% [markdown]
# ## Virtual Environment
#
# Create and activate a virtual environment:
#
# ```bash
# python -m venv irony
# source venv/bin/activate  # On Windows: venv\Scripts\activate
# ```
#
# or using conda
# ```
# conda create -n irony python=3.14.3
# conda activate irony
# ```
# Install kernel
#
# ```bash
# pip install --user ipykernel
# python -m ipykernel install --user --name=irony
# ```
#
# ## Install Dependencies
#
# ```bash
# pip install -r requirements.txt
# ```

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "allenai/OLMo-2-0425-1B-Instruct"  # lightest one

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.float16,   # use float32 if on CPU
    device_map="auto"            # auto-assigns to GPU if available
)

def check_model_loaded(model, tokenizer):
    test_input = "Hello, my name is"
    
    inputs = tokenizer(test_input, return_tensors="pt").to(model.device)
    
    with torch.no_grad():
        output = model.generate(**inputs, max_new_tokens=10)
    
    decoded = tokenizer.decode(output[0], skip_special_tokens=True)
    print(f"Input:  {test_input}")
    print(f"Output: {decoded}")
    print(f"Device: {model.device}")
    print(f"Dtype:  {model.dtype}")

check_model_loaded(model, tokenizer)
# Out:
# Loading weights:   0%|          | 0/179 [00:00<?, ?it/s]
# Input:  Hello, my name is
# Output: Hello, my name is [Your Name], and I am a [Your
# Device: mps:0
# Dtype:  torch.float16

# %%
import pandas as pd

files = {
    "condition1": "./conditions/Condition1(context_richness).csv",
    "condition2": "./conditions/Condition2(common_ground).csv",
    "condition3": "./conditions/Condition3(prompting_style).csv",
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       1 import pandas as pd
#       3 files = {
#       4     "condition1": "./conditions/Condition1(context_richness).csv",
#       5     "condition2": "./conditions/Condition2(common_ground).csv",
#       6     "condition3": "./conditions/Condition3(prompting_style).csv",
#       7 }
# ----> 9 print(df.head())
#
# NameError: name 'df' is not defined

# %%
def run_zero_shot(prompt: str, max_new_tokens: int = 20) -> str:
    # OLMo2 Instruct uses a chat template
    messages = [{"role": "user", "content": prompt}]

    input_ids = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt"
    )

        # If it's a BatchEncoding, unpack it; if it's already a tensor, keep it
    if hasattr(input_ids, "input_ids"):
        input_ids = input_ids["input_ids"]
    
    input_ids = input_ids.to(model.device)

    with torch.no_grad():
        output = model.generate(
            input_ids,
            max_new_tokens=max_new_tokens,
            do_sample=False
        )

    response = tokenizer.decode(
        output[0][input_ids.shape[-1]:],
        skip_special_tokens=True
    )
    return response.strip()

# %%
import pandas as pd
from tqdm import tqdm

# Load all 3
files = {
    "condition1": "./conditions/Condition1(context_richness).csv",
    "condition2": "./conditions/Condition2(common_ground).csv",
    "condition3": "./conditions/Condition3(prompting_style).csv",
}

for name, path in files.items():
    print(f"\nProcessing {name}...")
    
    df = pd.read_csv(path)
    print(df.head())  # sanity check
    
    tqdm.pandas()
    df["model_output"] = df["full_prompt"].progress_apply(run_zero_shot)
    
    output_path = f"results_olmo2_zeroshot_{name}.csv"
    df.to_csv(output_path, index=False)
    print(f"Saved: {output_path}")

print("\nAll done!")
# Out:
# 100%|█████████████████████████████████████████| 120/120 [08:32<00:00,  4.27s/it]

# %%
df.to_csv("results_olmo2_zeroshot.csv", index=False)
print("Done! Results saved.")
# Out:
# Done! Results saved.
